# %% [markdown]
# # Jupyter shortcuts
# up / down arrows: Navigate up and down \
# a / b: Create a cell above (a) or below (b) the current cell\
# m / y: Change the cell type to Markdown (m) or code (y)\
# Shift+up or Shift+down: Select multiple cells\
# Shift+m: Merge cells

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# d:\Programs\Projects\Analysis - European Cost of living\.venv\Scripts\python.exe
# 3.10.6 (tags/v3.10.6:9c7b4bd, Aug  1 2022, 21:53:49) [MSC v.1932 64 bit (AMD64)]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Everything works!")
print("Environment ready!")
print("pandas:", pd.__version__)
print("numpy:", np.__version__)
# Out:
# Everything works!
# Environment ready!
# pandas: 2.3.3
# numpy: 2.2.6

# %% [markdown]
# # Loading raw data PLI

# %%
from pathlib import Path

raw_dir = Path("../data/raw") #../ is to go back a level out of the notebooks directory

for file in raw_dir.iterdir(): #raw_dir.iterdir() lists the files inside that directory
    print(file.name, "-", file.stat().st_size, "bytes")
# Out:
# earn_nt_net_earnings_euro.csv - 5881 bytes
# earn_nt_net__earnings_50.csv - 5817 bytes
# eurostat_prc_ppp_ind_1_2025_pli_e011.csv - 9879 bytes

# %%
file_path = raw_dir / "eurostat_prc_ppp_ind_1_2025_pli_e011.csv"
#with .. as file is a better syntax; Python handers the closing of the file automatically
with open(file_path, "r", encoding="utf-8") as file: #r is for read the file; Encoding utf-8 is a very common encoding that contain country specific characters
    for _ in range(10): #we use _ not i because we don't need the numbers stored; we just need the action to be repeated
        print(file.readline().rstrip()) #file.readline().rstrip() two operations chained together, one reads the line and the other removes the newline character at the right / end of the line \n
# Out:
# STRUCTURE,STRUCTURE_ID,STRUCTURE_NAME,freq,Time frequency,indic_ppp,Purchasing power parities indicator,ppp_cat18,Analytical categories for purchasing power parities (PPPs) calculation (based on COICOP18),geo,Geopolitical entity (reporting),TIME_PERIOD,Time,OBS_VALUE,Observation value,OBS_FLAG,Observation status (Flag) V2 structure,CONF_STATUS,Confidentiality status (flag)
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,AT,Austria,2025,,113.0,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,BE,Belgium,2025,,116.2,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,BG,Bulgaria,2025,,62.5,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,CH,Switzerland,2025,,171.3,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,CY,Cyprus,2025,,89.2,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,CZ,Czechia,2025,,89.4,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,DE,Germany,2025,,108.3,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,DK,Denmark,2025,,139.7,,,,,
# dataflow,ESTAT:PRC_PPP_IND_1(1.0),"Purchasing power parities, price level indices, nominal and real expenditures by analytical categories - based on COICOP 2018",A,Annual,PLI_EU27_2020,Price level indices (EU27_2020=100),E011,Household final consumption expenditure,EA21,Euro area – 21 countries (from 2026),2025,,103.4,,,,,

# %%
df = pd.read_csv(file_path)

# %%
df.shape
# Out:
# (32, 19)

# %%
df.head()
# Out:
#   STRUCTURE              STRUCTURE_ID  \
# 0  dataflow  ESTAT:PRC_PPP_IND_1(1.0)
# 1  dataflow  ESTAT:PRC_PPP_IND_1(1.0)
# 2  dataflow  ESTAT:PRC_PPP_IND_1(1.0)
# 3  dataflow  ESTAT:PRC_PPP_IND_1(1.0)
# 4  dataflow  ESTAT:PRC_PPP_IND_1(1.0)
#
#                                       STRUCTURE_NAME freq Time frequency  \
# 0  Purchasing power parities, price level indices...    A         Annual
# 1  Purchasing power parities, price level indices...    A         Annual
# 2  Purchasing power parities, price level indices...    A         Annual
# 3  Purchasing power parities, price level indices...    A         Annual
# 4  Purchasing power parities, price level indices...    A         Annual
#
#        indic_ppp  Purchasing power parities indicator ppp_cat18  \
# 0  PLI_EU27_2020  Price level indices (EU27_2020=100)      E011
# 1  PLI_EU27_2020  Price level indices (EU27_2020=100)      E011
# 2  PLI_EU27_2020  Price level indices (EU27_2020=100)      E011
# 3  PLI_EU27_2020  Price level indices (EU27_2020=100)      E011
# 4  PLI_EU27_2020  Price level indices (EU27_2020=100)      E011
#
#   Analytical categories for purchasing power parities (PPPs) calculation (based on COICOP18)  \
# 0            Household final consumption expenditure
# 1            Household final consumption expenditure
# 2            Household final consumption expenditure
# 3            Household final consumption expenditure
# 4            Household final consumption expenditure
#
#   geo Geopolitical entity (reporting)  TIME_PERIOD  Time  OBS_VALUE  \
# 0  AT                         Austria         2025   NaN      113.0
# 1  BE                         Belgium         2025   NaN      116.2
# 2  BG                        Bulgaria         2025   NaN       62.5
# 3  CH                     Switzerland         2025   NaN      171.3
# 4  CY                          Cyprus         2025   NaN       89.2
#
#    Observation value  OBS_FLAG  Observation status (Flag) V2 structure  \
# 0                NaN       NaN                                     NaN
# 1                NaN       NaN                                     NaN
# 2                NaN       NaN                                     NaN
# 3                NaN       NaN                                     NaN
# 4                NaN       NaN                                     NaN
#
#    CONF_STATUS  Confidentiality status (flag)
# 0          NaN                            NaN
# 1          NaN                            NaN
# 2          NaN                            NaN
# 3          NaN                            NaN
# 4          NaN                            NaN

# %%
df.dtypes
# Out:
# STRUCTURE                                                                                      object
# STRUCTURE_ID                                                                                   object
# STRUCTURE_NAME                                                                                 object
# freq                                                                                           object
# Time frequency                                                                                 object
# indic_ppp                                                                                      object
# Purchasing power parities indicator                                                            object
# ppp_cat18                                                                                      object
# Analytical categories for purchasing power parities (PPPs) calculation (based on COICOP18)     object
# geo                                                                                            object
# Geopolitical entity (reporting)                                                                object
# TIME_PERIOD                                                                                     int64
# Time                                                                                          float64
# OBS_VALUE                                                                                     float64
# Observation value                                                                             float64
# OBS_FLAG                                                                                      float64
# Observation status (Flag) V2 structure                                                        float64
# CONF_STATUS                                                                                   float64
# Confidentiality status (flag)                                                                 float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 19 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0   STRUCTURE                                                                                   32 non-null     object
#  1   STRUCTURE_ID                                                                                32 non-null     object
#  2   STRUCTURE_NAME                                                                              32 non-null     object
#  3   freq                                                                                        32 non-null     object
#  4   Time frequency                                                                              32 non-null     object
#  5   indic_ppp                                                                                   32 non-null     object
#  6   Purchasing power parities indicator                                                         32 non-null     object
#  7   ppp_cat18                                                                                   32 non-null     object
#  8   Analytical categories for purchasing power parities (PPPs) calculation (based on COICOP18)  32 non-null     object
#  9   geo                                                                                         32 non-null     object
#  10  Geopolitical entity (reporting)                                                             32 non-null     object
#  11  TIME_PERIOD                                                                                 32 non-null     int64
#  12  Time                                                                                        0 non-null      float64
#  13  OBS_VALUE                                                                                   32 non-null     float64
#  14  Observation value                                                                           0 non-null      float64
#  15  OBS_FLAG                                                                                    0 non-null      float64
#  16  Observation status (Flag) V2 structure                                                      0 non-null      float64
#  17  CONF_STATUS                                                                                 0 non-null      float64
#  18  Confidentiality status (flag)                                                               0 non-null      float64
# dtypes: float64(7), int64(1), object(11)
# memory usage: 4.9+ KB

# %%
df[["geo","Geopolitical entity (reporting)"]]
# Out:
#           geo            Geopolitical entity (reporting)
# 0          AT                                    Austria
# 1          BE                                    Belgium
# 2          BG                                   Bulgaria
# 3          CH                                Switzerland
# 4          CY                                     Cyprus
# 5          CZ                                    Czechia
# 6          DE                                    Germany
# 7          DK                                    Denmark
# 8        EA21       Euro area – 21 countries (from 2026)
# 9          EE                                    Estonia
# 10         EL                                     Greece
# 11         ES                                      Spain
# 12  EU27_2020  European Union - 27 countries (from 2020)
# 13         FI                                    Finland
# 14         FR                                     France
# 15         HR                                    Croatia
# 16         HU                                    Hungary
# 17         IE                                    Ireland
# 18         IS                                    Iceland
# 19         IT                                      Italy
# 20         LT                                  Lithuania
# 21         LU                                 Luxembourg
# 22         LV                                     Latvia
# 23         MT                                      Malta
# 24         NL                                Netherlands
# 25         NO                                     Norway
# 26         PL                                     Poland
# 27         PT                                   Portugal
# 28         RO                                    Romania
# 29         SE                                     Sweden
# 30         SI                                   Slovenia
# 31         SK                                   Slovakia

# %%
df[["geo", "Geopolitical entity (reporting)", "OBS_VALUE"]]
# Out:
#           geo            Geopolitical entity (reporting)  OBS_VALUE
# 0          AT                                    Austria      113.0
# 1          BE                                    Belgium      116.2
# 2          BG                                   Bulgaria       62.5
# 3          CH                                Switzerland      171.3
# 4          CY                                     Cyprus       89.2
# 5          CZ                                    Czechia       89.4
# 6          DE                                    Germany      108.3
# 7          DK                                    Denmark      139.7
# 8        EA21       Euro area – 21 countries (from 2026)      103.4
# 9          EE                                    Estonia      101.2
# 10         EL                                     Greece       87.4
# 11         ES                                      Spain       91.6
# 12  EU27_2020  European Union - 27 countries (from 2020)      100.0
# 13         FI                                    Finland      120.8
# 14         FR                                     France      110.3
# 15         HR                                    Croatia       78.4
# 16         HU                                    Hungary       77.5
# 17         IE                                    Ireland      136.2
# 18         IS                                    Iceland      173.5
# 19         IT                                      Italy       97.1
# 20         LT                                  Lithuania       82.8
# 21         LU                                 Luxembourg      131.5
# 22         LV                                     Latvia       83.2
# 23         MT                                      Malta       91.9
# 24         NL                                Netherlands      115.6
# 25         NO                                     Norway      128.6
# 26         PL                                     Poland       73.3
# 27         PT                                   Portugal       86.6
# 28         RO                                    Romania       65.1
# 29         SE                                     Sweden      121.0
# 30         SI                                   Slovenia       89.3
# 31         SK                                   Slovakia       85.2

# %%
df_analysis = df.drop(
    df[df["geo"].isin(["CH","IS","NO","EA21"])].index
)

# %%
df_analysis.shape
# Out:
# (28, 19)

# %%
df_analysis["geo"].tolist()
# Out:
# ['AT',
#  'BE',
#  'BG',
#  'CY',
#  'CZ',
#  'DE',
#  'DK',
#  'EE',
#  'EL',
#  'ES',
#  'EU27_2020',
#  'FI',
#  'FR',
#  'HR',
#  'HU',
#  'IE',
#  'IT',
#  'LT',
#  'LU',
#  'LV',
#  'MT',
#  'NL',
#  'PL',
#  'PT',
#  'RO',
#  'SE',
#  'SI',
#  'SK']

# %% [markdown]
# # Data Validation / Quality Check PLI

# %%
#Duplicates
df_analysis["geo"].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Check for missing PLI values
df_analysis["OBS_VALUE"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #Check the year / indicator / expenditure category

# %%
df_analysis["TIME_PERIOD"].unique()
# Out:
# array([2025])

# %%
df_analysis["indic_ppp"].unique()
# Out:
# array(['PLI_EU27_2020'], dtype=object)

# %%
df_analysis["ppp_cat18"].unique()
# Out:
# array(['E011'], dtype=object)

# %% [markdown]
# # Descriptive statistics PLI

# %%
df_countries = df_analysis[
    df_analysis["geo"] != "EU27_2020"
]

# %%
df_countries.shape
# Out:
# (27, 19)

# %%
df_countries["OBS_VALUE"].describe()
# Out:
# count     27.000000
# mean      97.937037
# std       20.959854
# min       62.500000
# 25%       84.200000
# 50%       91.600000
# 75%      114.300000
# max      139.700000
# Name: OBS_VALUE, dtype: float64

# %%
df_analysis["OBS_VALUE"].describe() # with the aggregate the results are a bit of track
# Out:
# count     28.000000
# mean      98.010714
# std       20.571741
# min       62.500000
# 25%       84.700000
# 50%       91.750000
# 75%      113.650000
# max      139.700000
# Name: OBS_VALUE, dtype: float64

# %% [markdown]
# # Bar chart

# %%
#Sorting data
df_countries_sorted = df_countries.sort_values(
    "OBS_VALUE",
    ascending=True
)

# %%
df_countries_sorted[
    ["Geopolitical entity (reporting)", "OBS_VALUE"]
]
# Out:
#    Geopolitical entity (reporting)  OBS_VALUE
# 2                         Bulgaria       62.5
# 28                         Romania       65.1
# 26                          Poland       73.3
# 16                         Hungary       77.5
# 15                         Croatia       78.4
# 20                       Lithuania       82.8
# 22                          Latvia       83.2
# 31                        Slovakia       85.2
# 27                        Portugal       86.6
# 10                          Greece       87.4
# 4                           Cyprus       89.2
# 30                        Slovenia       89.3
# 5                          Czechia       89.4
# 11                           Spain       91.6
# 23                           Malta       91.9
# 19                           Italy       97.1
# 9                          Estonia      101.2
# 6                          Germany      108.3
# 14                          France      110.3
# 0                          Austria      113.0
# 24                     Netherlands      115.6
# 1                          Belgium      116.2
# 13                         Finland      120.8
# 29                          Sweden      121.0
# 21                      Luxembourg      131.5
# 17                         Ireland      136.2
# 7                          Denmark      139.7

# %%
fig, ax = plt.subplots(figsize=(15, 8))

ax.barh(
    df_countries_sorted["Geopolitical entity (reporting)"],
    df_countries_sorted["OBS_VALUE"]
)

#Adding the values at the end of the bars
# for bar in ax.patches:
#     value = bar.get_width()
    
#     ax.text(
#         value + 1,
#         bar.get_y() + bar.get_height() / 2,
#         f"{value:.1f}",
#         va="center"
#     )

#Adding the reference line at 100
ax.axvline(
    100,
    color = "red",
    linestyle="--",
    linewidth=2,
    label="EU27 reference = 100"
)

ax.set_xlabel("Price Level Index (EU27 = 100)")
ax.set_ylabel("Country")
ax.set_title("Household Consumption Price Levels in EU Countries, 2025")

ax.legend()

plt.show()

# %% [markdown]
# # Analytics

# %%
# the percentage by which the highest-PLI country exceeds the lowest-PLI country, using the lowest-priced country as the base
(
    df_countries["OBS_VALUE"].max()
    - df_countries["OBS_VALUE"].min()
) / df_countries["OBS_VALUE"].min() * 100
# Out:
# np.float64(123.51999999999998)

# %%
# the percentage by which the lowest-PLI country is below the highest-PLI country, using the highest-priced country as the base
(
    df_countries["OBS_VALUE"].max()
    - df_countries["OBS_VALUE"].min()
) / df_countries["OBS_VALUE"].max() * 100
# Out:
# np.float64(55.26127415891195)

# %%
min_pli = df_countries["OBS_VALUE"].min()
max_pli = df_countries["OBS_VALUE"].max()

print(f"Minimum PLI: {min_pli:.1f}")
print(f"Maximum PLI: {max_pli:.1f}")
# Out:
# Minimum PLI: 62.5
# Maximum PLI: 139.7

# %%
lowest_country = df_countries.loc[
    df_countries["OBS_VALUE"].idxmin(),
    "Geopolitical entity (reporting)"
]

highest_country = df_countries.loc[
    df_countries["OBS_VALUE"].idxmax(),
    "Geopolitical entity (reporting)"
]

print(f"Lowest PLI: {lowest_country} ({min_pli:.1f})")
print(f"Highest PLI: {highest_country} ({max_pli:.1f})")
# Out:
# Lowest PLI: Bulgaria (62.5)
# Highest PLI: Denmark (139.7)

# %% [markdown]
# # Conclusions

# %% [markdown]
# Our 2025 PLI dataset has:
#
# 27 EU countries\
# EU27 reference retained separately\
# no duplicate country observations\
# no missing PLI values\
# consistent year: 2025\
# consistent indicator: PLI_EU27_2020\
# consistent category: E011\
# Bulgaria: 62.5\
# Denmark: 139.7\
# unweighted country mean: 97.94\
# median: 91.6\

# %% [markdown]
# # Loading raw data income

# %%
from pathlib import Path

raw_data_path2 = Path("../data/raw")

for file in raw_data_path2.iterdir():
    print(file.name, "-", file.stat().st_size, "bytes")
# Out:
# earn_nt_net_earnings_euro.csv - 5881 bytes
# earn_nt_net__earnings_50.csv - 5817 bytes
# eurostat_prc_ppp_ind_1_2025_pli_e011.csv - 9879 bytes

# %%
file_path2 = raw_data_path2 / "earn_nt_net_earnings_euro.csv"

with open(file_path2, "r", encoding="utf-8") as file:
    for _ in range(10):
        print(file.readline().rstrip())
# Out:
# STRUCTURE,STRUCTURE_ID,STRUCTURE_NAME,freq,Time frequency,currency,Currency,estruct,Earnings structure,ecase,Earnings case,geo,Geopolitical entity (reporting),TIME_PERIOD,Time,OBS_VALUE,Observation value,OBS_FLAG,Observation status (Flag) V2 structure,CONF_STATUS,Confidentiality status (flag)
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,AT,Austria,2025,,36797.90,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,BE,Belgium,2025,,34642.30,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,BG,Bulgaria,2025,,13016.65,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,CY,Cyprus,2025,,23524.01,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,CZ,Czechia,2025,,19568.67,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,DE,Germany,2025,,31000.48,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,DK,Denmark,2025,,41981.24,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,EE,Estonia,2025,,20044.71,,,,,
# dataflow,ESTAT:EARN_NT_NET(1.0),Annual net earnings,A,Annual,EUR,Euro,NET,Net earning,P1_NCH_AW100,Single person without children earning 100% of the average earning,EL,Greece,2025,,15049.76,,,,,

# %%
df_earnings = pd.read_csv(file_path2)

# %%
df_earnings.shape
# Out:
# (28, 21)

# %%
df_earnings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               28 non-null     object
#  1   STRUCTURE_ID                            28 non-null     object
#  2   STRUCTURE_NAME                          28 non-null     object
#  3   freq                                    28 non-null     object
#  4   Time frequency                          28 non-null     object
#  5   currency                                28 non-null     object
#  6   Currency                                28 non-null     object
#  7   estruct                                 28 non-null     object
#  8   Earnings structure                      28 non-null     object
#  9   ecase                                   28 non-null     object
#  10  Earnings case                           28 non-null     object
#  11  geo                                     28 non-null     object
#  12  Geopolitical entity (reporting)         28 non-null     object
#  13  TIME_PERIOD                             28 non-null     int64
#  14  Time                                    0 non-null      float64
#  15  OBS_VALUE                               28 non-null     float64
#  16  Observation value                       0 non-null      float64
#  17  OBS_FLAG                                0 non-null      float64
#  18  Observation status (Flag) V2 structure  0 non-null      float64
#  19  CONF_STATUS                             0 non-null      float64
#  20  Confidentiality status (flag)           0 non-null      float64
# dtypes: float64(7), int64(1), object(13)
# memory usage: 4.7+ KB

# %%
df_earnings[["geo", "Geopolitical entity (reporting)", "OBS_VALUE"]]
# Out:
#           geo            Geopolitical entity (reporting)  OBS_VALUE
# 0          AT                                    Austria   36797.90
# 1          BE                                    Belgium   34642.30
# 2          BG                                   Bulgaria   13016.65
# 3          CY                                     Cyprus   23524.01
# 4          CZ                                    Czechia   19568.67
# 5          DE                                    Germany   31000.48
# 6          DK                                    Denmark   41981.24
# 7          EE                                    Estonia   20044.71
# 8          EL                                     Greece   15049.76
# 9          ES                                      Spain   25262.74
# 10  EU27_2020  European Union - 27 countries (from 2020)   26928.97
# 11         FI                                    Finland   33641.04
# 12         FR                                     France   30831.60
# 13         HR                                    Croatia   17256.07
# 14         HU                                    Hungary   12967.22
# 15         IE                                    Ireland   44263.30
# 16         IT                                      Italy   24471.27
# 17         LT                                  Lithuania   18650.38
# 18         LU                                 Luxembourg   54259.93
# 19         LV                                     Latvia   16792.67
# 20         MT                                      Malta   25543.95
# 21         NL                                Netherlands   35836.93
# 22         PL                                     Poland   16163.12
# 23         PT                                   Portugal   19708.63
# 24         RO                                    Romania   13232.74
# 25         SE                                     Sweden   34624.37
# 26         SI                                   Slovenia   22503.18
# 27         SK                                   Slovakia   15685.92

# %% [markdown]
# EU mean is 26928.97

# %% [markdown]
# # Data Validation / Quality Check income

# %%
df_earnings.columns.tolist()
# Out:
# ['STRUCTURE',
#  'STRUCTURE_ID',
#  'STRUCTURE_NAME',
#  'freq',
#  'Time frequency',
#  'currency',
#  'Currency',
#  'estruct',
#  'Earnings structure',
#  'ecase',
#  'Earnings case',
#  'geo',
#  'Geopolitical entity (reporting)',
#  'TIME_PERIOD',
#  'Time',
#  'OBS_VALUE',
#  'Observation value',
#  'OBS_FLAG',
#  'Observation status (Flag) V2 structure',
#  'CONF_STATUS',
#  'Confidentiality status (flag)']

# %%
#Duplicates
df_earnings["geo"].duplicated().sum()
# Out:
# np.int64(0)

# %%
#Check for missing PLI values
df_earnings["OBS_VALUE"].isna().sum()
# Out:
# np.int64(0)

# %%
df_earnings["TIME_PERIOD"].unique()
# Out:
# array([2025])

# %%
df_earnings["Earnings structure"].unique()
# Out:
# array(['Net earning'], dtype=object)

# %%
df_earnings["Earnings case"].unique()
# Out:
# array(['Single person without children earning 100% of the average earning'],
#       dtype=object)

# %%
df_earnings["currency"].unique()
# Out:
# array(['EUR'], dtype=object)

# %% [markdown]
# # Descriptive statistics income

# %%
df_earnings["OBS_VALUE"].describe()
# Out:
# count       28.000000
# mean     25866.062500
# std      10601.669596
# min      12967.220000
# 25%      17140.220000
# 50%      23997.640000
# 75%      33886.872500
# max      54259.930000
# Name: OBS_VALUE, dtype: float64

# %%
df_earnings_countries = df_earnings[
    df_earnings["geo"] != "EU27_2020"
]

# %%
df_earnings_countries["OBS_VALUE"].describe()
# Out:
# count       27.000000
# mean     25826.695556
# std      10801.538594
# min      12967.220000
# 25%      17024.370000
# 50%      23524.010000
# 75%      34132.705000
# max      54259.930000
# Name: OBS_VALUE, dtype: float64

# %%
comparison = pd.DataFrame({
    "PLI": df_countries["OBS_VALUE"],
    "Net earnings EUR": df_earnings_countries["OBS_VALUE"]
})

comparison.describe()
# Out:
#               PLI  Net earnings EUR
# count   27.000000         27.000000
# mean    97.937037      25826.695556
# std     20.959854      10801.538594
# min     62.500000      12967.220000
# 25%     84.200000      17024.370000
# 50%     91.600000      23524.010000
# 75%    114.300000      34132.705000
# max    139.700000      54259.930000

# %%
set(df_countries["geo"]) == set(df_earnings_countries["geo"])
# Out:
# True

# %%
pli = df_countries[
    ["geo", "Geopolitical entity (reporting)", "OBS_VALUE"]
].rename(
    columns={"OBS_VALUE": "pli"}
)

earnings = df_earnings_countries[
    ["geo", "OBS_VALUE"]
].rename(
    columns={"OBS_VALUE": "net_earnings_eur"}
)

# %%
df_combined = pli.merge(
    earnings,
    on="geo",
    how="inner"
)

# inner → observations present in both datasets
# left → keep everything from the left dataset
# right → keep everything from the right dataset
# outer → keep everything from both

# %%
df_combined.shape
# Out:
# (27, 4)

# %%
df_combined.head()
# Out:
#   geo Geopolitical entity (reporting)    pli  net_earnings_eur
# 0  AT                         Austria  113.0          36797.90
# 1  BE                         Belgium  116.2          34642.30
# 2  BG                        Bulgaria   62.5          13016.65
# 3  CY                          Cyprus   89.2          23524.01
# 4  CZ                         Czechia   89.4          19568.67

# %% [markdown]
# # Plots and Stats
# Are countries with higher net earnings also countries with higher price levels?

# %%
fig, ax = plt.subplots(figsize=(12, 8))

x = df_combined["pli"]
y = df_combined["net_earnings_eur"]

ax.scatter(x,y)

for _, row in df_combined.iterrows():
    ax.annotate(
        row["geo"],
        (row["pli"], row["net_earnings_eur"]),
        xytext=(5, 5),
        textcoords="offset points"
    )


# Linear regression line
slope, intercept = np.polyfit(x, y, 1)

x_line = np.linspace(x.min(), x.max(), 100)
y_line = slope * x_line + intercept

ax.plot(
    x_line,
    y_line,
    color="black",
    linestyle="-",
    linewidth=2,
    label="Linear trend"
)

# EU27 reference lines
ax.axvline(
    x=100,
    color="red",
    linestyle="--",
    linewidth=1.5,
    label="EU27 PLI = 100"
)

ax.axhline(
    y=df_earnings.loc[df_earnings["geo"] == "EU27_2020", "OBS_VALUE"].iloc[0],
    color="green",
    linestyle="--",
    linewidth=1.5,
    label=f"EU27 net earnings = €{df_earnings.loc[df_earnings['geo'] == 'EU27_2020', 'OBS_VALUE'].iloc[0]:,.2f}"
)

ax.set_xlabel("Price Level Index (EU27 = 100)")
ax.set_ylabel("Annual net earnings (€)")
ax.set_title(
    "Price Levels and Net Earnings in EU Countries, 2025"
)

ax.legend()

plt.show()

# %%
# Pearson correlation coefficient
correlation = df_combined["pli"].corr(
    df_combined["net_earnings_eur"]
)

r_squared = correlation ** 2


print(f"Pearson correlation: {correlation:.3f}")
print(f"R²: {r_squared:.3f}")
# Out:
# Pearson correlation: 0.937
# R²: 0.877

# %%
#Residual regression approach for caputuring the observations on Hungary and Luxemburg

# Calculating expecting earnings

slope, intercept = np.polyfit(x,y,1)
print(slope,intercept)
# Out:
# 482.7439685955376 -21451.81837619183

# %%
df_combined["predicted_earnings"] = (intercept + slope * df_combined["pli"])
print("Predicted earnings = ",intercept," + ", slope,"* PLI")
# Out:
# Predicted earnings =  -21451.81837619183  +  482.7439685955376 * PLI

# %%
df_combined["earnings_residual"] = (
    df_combined["net_earnings_eur"]
    - df_combined["predicted_earnings"]
)
print("Earnings residuals(i) = Net earnings(i) - Predicted earnings(i)")
# Out:
# Earnings residuals(i) = Net earnings(i) - Predicted earnings(i)

# %%
df_residuals = df_combined.sort_values(
    "earnings_residual",
    ascending=False
)

# %%
df_residuals[
    [
        "geo",
        "pli",
        "net_earnings_eur",
        "predicted_earnings",
        "earnings_residual"
    ]
]
# Out:
#    geo    pli  net_earnings_eur  predicted_earnings  earnings_residual
# 17  LU  131.5          54259.93        42029.013494       12230.916506
# 2   BG   62.5          13016.65         8719.679661        4296.970339
# 0   AT  113.0          36797.90        33098.250075        3699.649925
# 23  RO   65.1          13232.74         9974.813979        3257.926021
# 19  MT   91.9          25543.95        22912.352338        2631.597662
# 9   ES   91.6          25262.74        22767.529147        2495.210853
# 21  PL   73.3          16163.12        13933.314522        2229.805478
# 3   CY   89.2          23524.01        21608.943623        1915.066377
# 20  NL  115.6          35836.93        34353.384393        1483.545607
# 12  HR   78.4          17256.07        16395.308762         860.761238
# 25  SI   89.3          22503.18        21657.218019         845.961981
# 5   DE  108.3          31000.48        30829.353423         171.126577
# 16  LT   82.8          18650.38        18519.382224         130.997776
# 1   BE  116.2          34642.30        34643.030775          -0.730775
# 14  IE  136.2          44263.30        44297.910147         -34.610147
# 22  PT   86.6          19708.63        20353.809304        -645.179304
# 15  IT   97.1          24471.27        25422.620974        -951.350974
# 11  FR  110.3          30831.60        31794.841360        -963.241360
# 18  LV   83.2          16792.67        18712.479811       -1919.809811
# 4   CZ   89.4          19568.67        21705.492416       -2136.822416
# 24  SE  121.0          34624.37        36960.201824       -2335.831824
# 13  HU   77.5          12967.22        15960.839190       -2993.619190
# 10  FI  120.8          33641.04        36863.653030       -3222.613030
# 26  SK   85.2          15685.92        19677.967748       -3992.047748
# 6   DK  139.7          41981.24        45987.514037       -4006.274037
# 8   EL   87.4          15049.76        20740.004479       -5690.244479
# 7   EE  101.2          20044.71        27401.871246       -7357.161246

# %%
df_combined.info(
)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 6 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   geo                              27 non-null     object
#  1   Geopolitical entity (reporting)  27 non-null     object
#  2   pli                              27 non-null     float64
#  3   net_earnings_eur                 27 non-null     float64
#  4   predicted_earnings               27 non-null     float64
#  5   earnings_residual                27 non-null     float64
# dtypes: float64(4), object(2)
# memory usage: 1.4+ KB

# %%
df_combined["earnings_to_pli"] = (
    df_combined["net_earnings_eur"]
    / df_combined["pli"]
)

# %%
df_affordability = df_combined.sort_values(
    "earnings_to_pli",
    ascending=False
)

df_affordability[
    [
        "geo",
        "pli",
        "net_earnings_eur",
        "earnings_to_pli"
    ]
]
# Out:
#    geo    pli  net_earnings_eur  earnings_to_pli
# 17  LU  131.5          54259.93       412.623042
# 0   AT  113.0          36797.90       325.645133
# 14  IE  136.2          44263.30       324.987518
# 20  NL  115.6          35836.93       310.008045
# 6   DK  139.7          41981.24       300.509950
# 1   BE  116.2          34642.30       298.126506
# 5   DE  108.3          31000.48       286.246353
# 24  SE  121.0          34624.37       286.151818
# 11  FR  110.3          30831.60       279.524932
# 10  FI  120.8          33641.04       278.485430
# 19  MT   91.9          25543.95       277.953754
# 9   ES   91.6          25262.74       275.794105
# 3   CY   89.2          23524.01       263.722085
# 15  IT   97.1          24471.27       252.021318
# 25  SI   89.3          22503.18       251.995297
# 22  PT   86.6          19708.63       227.582333
# 16  LT   82.8          18650.38       225.246135
# 21  PL   73.3          16163.12       220.506412
# 12  HR   78.4          17256.07       220.102934
# 4   CZ   89.4          19568.67       218.888926
# 2   BG   62.5          13016.65       208.266400
# 23  RO   65.1          13232.74       203.267896
# 18  LV   83.2          16792.67       201.834976
# 7   EE  101.2          20044.71       198.070257
# 26  SK   85.2          15685.92       184.107042
# 8   EL   87.4          15049.76       172.194050
# 13  HU   77.5          12967.22       167.318968

# %%
eu27_earnings = df_earnings.loc[
    df_earnings["geo"] == "EU27_2020",
    "OBS_VALUE"
].iloc[0]
print(eu27_earnings)
# Out:
# 26928.97

# %%
df_combined["affordability_index"] = (
    (df_combined["earnings_to_pli"])
    / (eu27_earnings / 100)
) * 100

# %%
df_affordability = df_combined.sort_values(
    "affordability_index",
    ascending=True
)

df_affordability[
    [
        "geo",
        "pli",
        "net_earnings_eur",
        "earnings_to_pli",
        "affordability_index"
    ]
]
# Out:
#    geo    pli  net_earnings_eur  earnings_to_pli  affordability_index
# 13  HU   77.5          12967.22       167.318968            62.133445
# 8   EL   87.4          15049.76       172.194050            63.943794
# 26  SK   85.2          15685.92       184.107042            68.367651
# 7   EE  101.2          20044.71       198.070257            73.552853
# 18  LV   83.2          16792.67       201.834976            74.950871
# 23  RO   65.1          13232.74       203.267896            75.482982
# 2   BG   62.5          13016.65       208.266400            77.339163
# 4   CZ   89.4          19568.67       218.888926            81.283809
# 12  HR   78.4          17256.07       220.102934            81.734628
# 21  PL   73.3          16163.12       220.506412            81.884458
# 16  LT   82.8          18650.38       225.246135            83.644542
# 22  PT   86.6          19708.63       227.582333            84.512082
# 25  SI   89.3          22503.18       251.995297            93.577770
# 15  IT   97.1          24471.27       252.021318            93.587433
# 3   CY   89.2          23524.01       263.722085            97.932481
# 9   ES   91.6          25262.74       275.794105           102.415393
# 19  MT   91.9          25543.95       277.953754           103.217373
# 10  FI  120.8          33641.04       278.485430           103.414810
# 11  FR  110.3          30831.60       279.524932           103.800826
# 24  SE  121.0          34624.37       286.151818           106.261702
# 5   DE  108.3          31000.48       286.246353           106.296807
# 1   BE  116.2          34642.30       298.126506           110.708470
# 6   DK  139.7          41981.24       300.509950           111.593555
# 20  NL  115.6          35836.93       310.008045           115.120647
# 14  IE  136.2          44263.30       324.987518           120.683234
# 0   AT  113.0          36797.90       325.645133           120.927437
# 17  LU  131.5          54259.93       412.623042           153.226448

# %%
fig, ax = plt.subplots(figsize=(10, 8))

ax.barh(
    df_affordability["geo"],
    df_affordability["affordability_index"]
)

ax.axvline(
    100,
    linestyle="--",
    linewidth=2,
    label="EU27 reference = 100"
)

ax.set_xlabel("Earnings-to-Price-Level Affordability Index")
ax.set_ylabel("Country")
ax.set_title(
    "Relative Earnings-to-Price-Level Position, 2025"
)

ax.legend()

plt.tight_layout()
plt.show()

# %%
# Normalize variables
# calculate each country's earnings and price level relative to the EU27
# price_level_index is simply the PLI because the PLI is already expressed with EU27 = 100

df_combined["earnings_index"] = (
    df_combined["net_earnings_eur"]
    / eu27_earnings
) * 100

df_combined["price_level_index"] = df_combined["pli"]

# %%
df_combined[
    [
        "geo",
        "earnings_index",
        "price_level_index",
        "affordability_index"
    ]
].sort_values(
    "affordability_index",
    ascending=False
)
# Out:
#    geo  earnings_index  price_level_index  affordability_index
# 17  LU      201.492779              131.5           153.226448
# 0   AT      136.648004              113.0           120.927437
# 14  IE      164.370564              136.2           120.683234
# 20  NL      133.079468              115.6           115.120647
# 6   DK      155.896197              139.7           111.593555
# 1   BE      128.643242              116.2           110.708470
# 5   DE      115.119442              108.3           106.296807
# 24  SE      128.576659              121.0           106.261702
# 11  FR      114.492311              110.3           103.800826
# 10  FI      124.925090              120.8           103.414810
# 19  MT       94.856766               91.9           103.217373
# 9   ES       93.812500               91.6           102.415393
# 3   CY       87.355773               89.2            97.932481
# 15  IT       90.873398               97.1            93.587433
# 25  SI       83.564949               89.3            93.577770
# 22  PT       73.187463               86.6            84.512082
# 16  LT       69.257680               82.8            83.644542
# 21  PL       60.021308               73.3            81.884458
# 12  HR       64.079948               78.4            81.734628
# 4   CZ       72.667726               89.4            81.283809
# 2   BG       48.336977               62.5            77.339163
# 23  RO       49.139421               65.1            75.482982
# 18  LV       62.359125               83.2            74.950871
# 7   EE       74.435487              101.2            73.552853
# 26  SK       58.249239               85.2            68.367651
# 8   EL       55.886876               87.4            63.943794
# 13  HU       48.153420               77.5            62.133445

# %% [markdown]
# # 50% Analysis

# %% [markdown]
# Loading data

# %%
df_earnings_50 = pd.read_csv(r"D:\Programs\Projects\Analysis - European Cost of living\data\raw\earn_nt_net__earnings_50.csv")

# %%
df_earnings_50.shape
# Out:
# (28, 21)

# %%
df_earnings_50.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 21 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STRUCTURE                               28 non-null     object
#  1   STRUCTURE_ID                            28 non-null     object
#  2   STRUCTURE_NAME                          28 non-null     object
#  3   freq                                    28 non-null     object
#  4   Time frequency                          28 non-null     object
#  5   currency                                28 non-null     object
#  6   Currency                                28 non-null     object
#  7   estruct                                 28 non-null     object
#  8   Earnings structure                      28 non-null     object
#  9   ecase                                   28 non-null     object
#  10  Earnings case                           28 non-null     object
#  11  geo                                     28 non-null     object
#  12  Geopolitical entity (reporting)         28 non-null     object
#  13  TIME_PERIOD                             28 non-null     int64
#  14  Time                                    0 non-null      float64
#  15  OBS_VALUE                               28 non-null     float64
#  16  Observation value                       0 non-null      float64
#  17  OBS_FLAG                                0 non-null      float64
#  18  Observation status (Flag) V2 structure  0 non-null      float64
#  19  CONF_STATUS                             0 non-null      float64
#  20  Confidentiality status (flag)           0 non-null      float64
# dtypes: float64(7), int64(1), object(13)
# memory usage: 4.7+ KB

# %% [markdown]
# # Descriptive statistics

# %%
df_earnings_50["OBS_VALUE"].describe()
# Out:
# count       28.000000
# mean     15922.270714
# std       7746.099165
# min       6483.610000
# 25%       9549.527500
# 50%      14252.450000
# 75%      19814.222500
# max      36112.840000
# Name: OBS_VALUE, dtype: float64

# %%
eu27_50 = df_earnings_50.loc[
    df_earnings_50["geo"] == "EU27_2020",
    "OBS_VALUE"
].iloc[0]

# %%
print(eu27_earnings)
# Out:
# 26928.97

# %%
df_earnings_50 = df_earnings_50[
    ~df_earnings_50["geo"].isin(["EU27_2020"])
]

# %%
df_earnings_50.shape
# Out:
# (27, 21)

# %%
df_earnings_50[["geo", "Geopolitical entity (reporting)", "OBS_VALUE"]].sort_values("OBS_VALUE")
# Out:
#    geo Geopolitical entity (reporting)  OBS_VALUE
# 14  HU                         Hungary    6483.61
# 2   BG                        Bulgaria    6508.32
# 24  RO                         Romania    6741.43
# 27  SK                        Slovakia    8389.57
# 8   EL                          Greece    8650.50
# 19  LV                          Latvia    9176.64
# 22  PL                          Poland    9370.90
# 13  HR                         Croatia    9609.07
# 17  LT                       Lithuania   10771.32
# 7   EE                         Estonia   11748.91
# 26  SI                        Slovenia   12127.39
# 3   CY                          Cyprus   12265.01
# 4   CZ                         Czechia   12277.93
# 23  PT                        Portugal   13608.18
# 9   ES                           Spain   14896.72
# 16  IT                           Italy   14913.23
# 20  MT                           Malta   16327.29
# 5   DE                         Germany   18861.79
# 25  SE                          Sweden   19533.49
# 12  FR                          France   19721.26
# 11  FI                         Finland   20093.11
# 0   AT                         Austria   23117.84
# 6   DK                         Denmark   23645.50
# 1   BE                         Belgium   25346.00
# 21  NL                     Netherlands   28369.52
# 15  IE                         Ireland   30433.84
# 18  LU                      Luxembourg   36112.84

# %% [markdown]
# Creating a new dataFrame with the data from the previous analysis

# %%
df_combined.columns
# Out:
# Index(['geo', 'Geopolitical entity (reporting)', 'pli', 'net_earnings_eur',
#        'predicted_earnings', 'earnings_residual', 'earnings_to_pli',
#        'affordability_index', 'earnings_index', 'price_level_index'],
#       dtype='object')

# %%
(df_combined["pli"] == df_combined["price_level_index"]).all()
# Out:
# np.True_

# %%
df_combined = df_combined.drop(columns=["price_level_index"])

# %%
df_50 = df_earnings_50[["geo", "OBS_VALUE"]].copy()

df_50 = df_50.rename(columns={
    "OBS_VALUE": "net_earnings_50_eur"
})

# %%
df_combined_50 = df_combined[["geo", "pli"]].merge(
    df_50,
    on="geo",
    how="inner"
)

# %%
df_combined_50.columns
# Out:
# Index(['geo', 'pli', 'net_earnings_50_eur'], dtype='object')

# %%
df_combined_50["earnings_to_pli_50"] = (
    df_combined_50["net_earnings_50_eur"]
    / df_combined_50["pli"]
)

# %%
df_combined_50.sort_values(
    "earnings_to_pli_50",
    ascending=False
)
# Out:
#    geo    pli  net_earnings_50_eur  earnings_to_pli_50
# 17  LU  131.5             36112.84          274.622357
# 20  NL  115.6             28369.52          245.411073
# 14  IE  136.2             30433.84          223.449633
# 1   BE  116.2             25346.00          218.123924
# 0   AT  113.0             23117.84          204.582655
# 11  FR  110.3             19721.26          178.796555
# 19  MT   91.9             16327.29          177.663656
# 5   DE  108.3             18861.79          174.162419
# 6   DK  139.7             23645.50          169.259127
# 10  FI  120.8             20093.11          166.333692
# 9   ES   91.6             14896.72          162.627948
# 24  SE  121.0             19533.49          161.433802
# 22  PT   86.6             13608.18          157.138337
# 15  IT   97.1             14913.23          153.586303
# 3   CY   89.2             12265.01          137.500112
# 4   CZ   89.4             12277.93          137.337025
# 25  SI   89.3             12127.39          135.805039
# 16  LT   82.8             10771.32          130.088406
# 21  PL   73.3              9370.90          127.843111
# 12  HR   78.4              9609.07          122.564668
# 7   EE  101.2             11748.91          116.095949
# 18  LV   83.2              9176.64          110.296154
# 2   BG   62.5              6508.32          104.133120
# 23  RO   65.1              6741.43          103.554992
# 8   EL   87.4              8650.50           98.975973
# 26  SK   85.2              8389.57           98.469131
# 13  HU   77.5              6483.61           83.659484

# %% [markdown]
# Calculating affordability index for the 50% earners

# %%
df_combined_50["affordability_index_50"] = (
    df_combined_50["earnings_to_pli_50"]
    / (eu27_50 / 100) * 100
)

# %%
df_combined_50.sort_values(
    "affordability_index_50",
    ascending=False
)
# Out:
#    geo    pli  net_earnings_50_eur  earnings_to_pli_50  affordability_index_50
# 17  LU  131.5             36112.84          274.622357              164.224543
# 20  NL  115.6             28369.52          245.411073              146.756155
# 14  IE  136.2             30433.84          223.449633              133.623184
# 1   BE  116.2             25346.00          218.123924              130.438403
# 0   AT  113.0             23117.84          204.582655              122.340706
# 11  FR  110.3             19721.26          178.796555              106.920583
# 19  MT   91.9             16327.29          177.663656              106.243108
# 5   DE  108.3             18861.79          174.162419              104.149364
# 6   DK  139.7             23645.50          169.259127              101.217188
# 10  FI  120.8             20093.11          166.333692               99.467774
# 9   ES   91.6             14896.72          162.627948               97.251734
# 24  SE  121.0             19533.49          161.433802               96.537633
# 22  PT   86.6             13608.18          157.138337               93.968939
# 15  IT   97.1             14913.23          153.586303               91.844818
# 3   CY   89.2             12265.01          137.500112               82.225254
# 4   CZ   89.4             12277.93          137.337025               82.127727
# 25  SI   89.3             12127.39          135.805039               81.211598
# 16  LT   82.8             10771.32          130.088406               77.793044
# 21  PL   73.3              9370.90          127.843111               76.450354
# 12  HR   78.4              9609.07          122.564668               73.293838
# 7   EE  101.2             11748.91          116.095949               69.425535
# 18  LV   83.2              9176.64          110.296154               65.957250
# 2   BG   62.5              6508.32          104.133120               62.271747
# 23  RO   65.1              6741.43          103.554992               61.926026
# 8   EL   87.4              8650.50           98.975973               59.187766
# 26  SK   85.2              8389.57           98.469131               58.884675
# 13  HU   77.5              6483.61           83.659484               50.028485

# %% [markdown]
# # Liniar Regression

# %%
slope_50, intercept_50 = np.polyfit(
    df_combined_50["pli"],
    df_combined_50["net_earnings_50_eur"],
    1
)

# %%
df_combined_50["predicted_earnings_50"] = (
    slope_50 * df_combined_50["pli"] + intercept_50
)

# %%
df_combined_50["earnings_residual_50"] = (
    df_combined_50["net_earnings_50_eur"]
    - df_combined_50["predicted_earnings_50"]
)

# %% [markdown]
# Pearson and R squared coefficients

# %%
correlation_50 = df_combined_50["pli"].corr(
    df_combined_50["net_earnings_50_eur"]
)

r_squared_50 = correlation_50 ** 2

print(correlation_50, r_squared_50)
# Out:
# 0.9039914316589825 0.8172005085128569

# %%
df_analysis_50 = df_combined_50[
    [
        "geo",
        "pli",
        "net_earnings_50_eur",
        "predicted_earnings_50",
        "earnings_residual_50",
        "earnings_to_pli_50",
        "affordability_index_50"
    ]
].copy()

# %%
df_comparison = df_combined.merge(
    df_analysis_50,
    on="geo",
    how="inner",
    suffixes=("_100", "_50")
)

# %%
df_comparison.columns
# Out:
# Index(['geo', 'Geopolitical entity (reporting)', 'pli_100', 'net_earnings_eur',
#        'predicted_earnings', 'earnings_residual', 'earnings_to_pli',
#        'affordability_index', 'earnings_index', 'pli_50',
#        'net_earnings_50_eur', 'predicted_earnings_50', 'earnings_residual_50',
#        'earnings_to_pli_50', 'affordability_index_50'],
#       dtype='object')

# %%
(df_comparison["pli_100"] == df_comparison["pli_50"]).all()
# Out:
# np.True_

# %%
df_comparison = df_comparison.drop(columns=["pli_50"])

# %%
df_comparison = df_comparison.rename(
    columns={"pli_100": "pli"}
)

# %%
df_comparison["affordability_change"] = (
    df_comparison["affordability_index_50"]
    - df_comparison["affordability_index"]
)

# %%
df_comparison.info(

)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   geo                              27 non-null     object
#  1   Geopolitical entity (reporting)  27 non-null     object
#  2   pli                              27 non-null     float64
#  3   net_earnings_eur                 27 non-null     float64
#  4   predicted_earnings               27 non-null     float64
#  5   earnings_residual                27 non-null     float64
#  6   earnings_to_pli                  27 non-null     float64
#  7   affordability_index              27 non-null     float64
#  8   earnings_index                   27 non-null     float64
#  9   net_earnings_50_eur              27 non-null     float64
#  10  predicted_earnings_50            27 non-null     float64
#  11  earnings_residual_50             27 non-null     float64
#  12  earnings_to_pli_50               27 non-null     float64
#  13  affordability_index_50           27 non-null     float64
#  14  affordability_change             27 non-null     float64
# dtypes: float64(13), object(2)
# memory usage: 3.3+ KB

# %%
df_comparison[
    [
        "geo",
        "affordability_index",
        "affordability_index_50",
        "affordability_change"
    ]
].sort_values(
    "affordability_change",
    ascending=False
)
# Out:
#    geo  affordability_index  affordability_index_50  affordability_change
# 20  NL           115.120647              146.756155             31.635508
# 1   BE           110.708470              130.438403             19.729934
# 14  IE           120.683234              133.623184             12.939950
# 17  LU           153.226448              164.224543             10.998095
# 22  PT            84.512082               93.968939              9.456857
# 11  FR           103.800826              106.920583              3.119757
# 19  MT           103.217373              106.243108              3.025735
# 0   AT           120.927437              122.340706              1.413269
# 4   CZ            81.283809               82.127727              0.843918
# 15  IT            93.587433               91.844818             -1.742615
# 5   DE           106.296807              104.149364             -2.147443
# 10  FI           103.414810               99.467774             -3.947036
# 7   EE            73.552853               69.425535             -4.127318
# 8   EL            63.943794               59.187766             -4.756028
# 9   ES           102.415393               97.251734             -5.163659
# 21  PL            81.884458               76.450354             -5.434104
# 16  LT            83.644542               77.793044             -5.851498
# 12  HR            81.734628               73.293838             -8.440789
# 18  LV            74.950871               65.957250             -8.993621
# 26  SK            68.367651               58.884675             -9.482976
# 24  SE           106.261702               96.537633             -9.724069
# 6   DK           111.593555              101.217188            -10.376367
# 13  HU            62.133445               50.028485            -12.104960
# 25  SI            93.577770               81.211598            -12.366172
# 23  RO            75.482982               61.926026            -13.556956
# 2   BG            77.339163               62.271747            -15.067416
# 3   CY            97.932481               82.225254            -15.707227

# %% [markdown]
# # Plot

# %%
df_plot = df_comparison.sort_values(
    "affordability_change"
).copy()

fig, ax = plt.subplots(figsize=(10, 12))

y = range(len(df_plot))

for i, (_, row) in enumerate(df_plot.iterrows()):

    # Connection
    ax.plot(
        [row["affordability_index"], row["affordability_index_50"]],
        [i, i],
        color="gray",
        linewidth=2,
        alpha=0.6
    )

    # 100% earner
    ax.scatter(
        row["affordability_index"],
        i,
        color="steelblue",
        s=70,
        label="100% average earnings" if i == 0 else ""
    )

    # 50% earner
    ax.scatter(
        row["affordability_index_50"],
        i,
        color="darkorange",
        s=70,
        label="50% average earnings" if i == 0 else ""
    )

ax.set_yticks(list(y))
ax.set_yticklabels(df_plot["geo"])

# EU27 benchmark
ax.axvline(
    100,
    color="black",
    linestyle="--",
    linewidth=1.5,
    alpha=0.7
)

ax.set_xlabel("Affordability Index (EU27 = 100)")
ax.set_ylabel("Country")

ax.set_title(
    "Affordability: 100% vs 50% of Average Earnings"
)

ax.legend()

plt.tight_layout()
plt.show()

# %%
# Export processed data
processed_path = Path("processed")
processed_path.mkdir(exist_ok=True)

df_comparison.to_csv(
    processed_path / "eu27_earnings_affordability_final.csv",
    index=False
)

# %%
df_comparison.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Data columns (total 15 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   geo                              27 non-null     object
#  1   Geopolitical entity (reporting)  27 non-null     object
#  2   pli                              27 non-null     float64
#  3   net_earnings_eur                 27 non-null     float64
#  4   predicted_earnings               27 non-null     float64
#  5   earnings_residual                27 non-null     float64
#  6   earnings_to_pli                  27 non-null     float64
#  7   affordability_index              27 non-null     float64
#  8   earnings_index                   27 non-null     float64
#  9   net_earnings_50_eur              27 non-null     float64
#  10  predicted_earnings_50            27 non-null     float64
#  11  earnings_residual_50             27 non-null     float64
#  12  earnings_to_pli_50               27 non-null     float64
#  13  affordability_index_50           27 non-null     float64
#  14  affordability_change             27 non-null     float64
# dtypes: float64(13), object(2)
# memory usage: 3.3+ KB

# %%
print(processed_path / "eu27_earnings_affordability_final.csv")
# Out:
# processed\eu27_earnings_affordability_final.csv
